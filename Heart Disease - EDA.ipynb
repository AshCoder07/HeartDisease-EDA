# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("heart.csv")

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.shape
# Out:
# (918, 12)

# %% [markdown]
# ## Distribution Charts for Numerical data

# %%
sns.displot(df["Age"],kde=True)

# %%
sns.distplot(df["Age"],hist=True,kde=False)
# Out:
# C:\Users\aswin\AppData\Local\Temp\ipykernel_58804\2786820752.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"],hist=True,kde=False)
# <Axes: xlabel='Age'>

# %%
sns.distplot(df["Age"],rug=True,kde=False,hist=False)
# Out:
# C:\Users\aswin\AppData\Local\Temp\ipykernel_58804\589031690.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"],rug=True,kde=False,hist=False)
# <Axes: xlabel='Age'>

# %%
sns.distplot(df["Age"],hist=True,kde=True,rug=True)
# Out:
# C:\Users\aswin\AppData\Local\Temp\ipykernel_58804\593245275.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"],hist=True,kde=True,rug=True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df["Age"],bins=10)
# Out:
# C:\Users\aswin\AppData\Local\Temp\ipykernel_58804\1677667674.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"],bins=10)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.displot(df["RestingBP"],kde=True,color="red")

# %%
sns.distplot(df["Cholesterol"],kde=True,color="red")
# Out:
# C:\Users\aswin\AppData\Local\Temp\ipykernel_58804\618714184.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Cholesterol"],kde=True,color="red")
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
sns.distplot(df["FastingBS"],kde=True,color="red")
# Out:
# C:\Users\aswin\AppData\Local\Temp\ipykernel_58804\1773044202.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["FastingBS"],kde=True,color="red")
# <Axes: xlabel='FastingBS', ylabel='Density'>

# %%
sns.distplot(df["MaxHR"],kde=True,color="red")
# Out:
# C:\Users\aswin\AppData\Local\Temp\ipykernel_58804\2875114864.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["MaxHR"],kde=True,color="red")
# <Axes: xlabel='MaxHR', ylabel='Density'>

# %%
sns.distplot(df["Oldpeak"],kde=True,color="red")
# Out:
# C:\Users\aswin\AppData\Local\Temp\ipykernel_58804\118331060.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Oldpeak"],kde=True,color="red")
# <Axes: xlabel='Oldpeak', ylabel='Density'>

# %% [markdown]
# ## Pie charts for Categorical data

# %%
df.groupby("Sex").size().plot(kind="pie",autopct="%.1f")
# Out:
# <Axes: >

# %%
df.groupby("ChestPainType").size().plot(kind="pie",autopct="%.1f")
# Out:
# <Axes: >

# %%
df.groupby("RestingECG").size().plot(kind="pie",autopct="%.1f")
# Out:
# <Axes: >

# %%
df.groupby("ExerciseAngina").size().plot(kind="pie",autopct="%.1f")
# Out:
# <Axes: >

# %%
df.groupby("ST_Slope").size().plot(kind="pie",autopct="%.1f")
# Out:
# <Axes: >

# %%
df.groupby("HeartDisease").size().plot(kind="pie",autopct="%.1f")
# Out:
# <Axes: >

# %% [markdown]
# ## Violin Plot

# %%
sns.violinplot(data=df,x="Age")
# Out:
# <Axes: xlabel='Age'>

# %%
sns.violinplot(data=df,x="HeartDisease",y="Sex")
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %%
sns.violinplot(data=df,x="HeartDisease",y="Age")
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.violinplot(data=df,x="HeartDisease",y="Cholesterol")
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %% [markdown]
# ## Correlation - Heatmap

# %%
df.corr(numeric_only=True)
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
sns.heatmap(data=df.corr(numeric_only=True),cmap="Greens")
# Out:
# <Axes: >

# %% [markdown]
# ## Correlation - Jointplot

# %%
sns.jointplot(data=df,x="Age",y="MaxHR")

# %%
sns.jointplot(data=df,x="Age",y="Age")

# %%
sns.jointplot(data=df,x="HeartDisease",y="Oldpeak")

# %%
sns.jointplot(data=df,x="Age",y="MaxHR",kind="hex")

# %%
sns.jointplot(data=df,x="Age",y="MaxHR",kind="reg")

# %%
sns.jointplot(data=df,x="Cholesterol",y="FastingBS",kind="reg")

# %%
sns.jointplot(data=df,x="HeartDisease",y="MaxHR",kind="reg")

# %% [markdown]
# ## Correlation - Pairplot

# %%
sns.pairplot(data=df)
